# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %% [markdown]
# Lecture des données :

# %%
dossier_projet = r"C:\Users\khale\OneDrive\Documents\Ensae\Python pour le data scientist\Projets\dvf_ensae_sbra".replace("\\","/")

# %%
donnees = pd.read_csv(dossier_projet + "/good_data/donnees_model/donnees_train.csv", index_col = 0)

# %% [markdown]
# Un peu de traitement de la base

# %%
donnees["arrondissement"] = donnees["arrondissement"].astype("object")

donnees["pp"] = donnees["pp"].astype("object")

donnees["mois"] = donnees["datemut"].str[5:7].astype("object")

donnees_V2 = donnees.drop(columns = ["nblot", "nbpar", "nblocmut", "nblocdep","datemut"])

# %%
rf = RandomForestRegressor(random_state=42, max_features = "sqrt",n_jobs = -1)

# %%
donnees_V2.drop(columns = ["valfoncact"])
# Out:
#         idmutation  sbati pp  sbati_squa       Ind       Men  Men_pauv  \
# 114252     5763023     57  3        3249    9657.0    4847.0  5.827166
# 55040      5867011    202  2       40804  395466.0  178068.0  1.180403
# 121251     5198077     60  4        3600  344121.0  185991.0  1.456980
# 151117     5748427     36  2        1296  346338.0  201924.0  1.513290
# 128041     5750209     49  2        2401  520631.5  266327.0  1.242081
# ...            ...    ... ..         ...       ...       ...       ...
# 141348     5856547     71  3        5041  415917.5  202315.0  1.840807
# 50768      5304471     30  1         900  206252.5   90390.0  2.233747
# 93349      5765279     40  2        1600  487272.0  254538.0  1.638526
# 109070     5310272     78  4        6084  360885.0  175665.0  1.595055
# 83020      5598668     53  3        2809  570015.0  324996.0  1.263782
#
#          Men_1ind  Men_5ind   Men_prop  ...  AUTRES_SERV    COMMERCE  \
# ...

# %%
donnees_V2_X = donnees_V2.drop(columns = ["valfoncact"]).to_numpy()
donnees_V2_Y = donnees_V2["valfoncact"].to_numpy()

# %%
rf.fit(donnees_V2_X, donnees_V2_Y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-9a464b87627b> in <module>
# ----> 1 rf.fit(donnees_V2_X, donnees_V2_Y)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
# ...
